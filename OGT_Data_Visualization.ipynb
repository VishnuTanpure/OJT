# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Figure Properties
# rcParams : Runtime Configuration Parameters
plt.rcParams['figure.figsize']=(9,6)
plt.rcParams['figure.dpi']=80
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/Salaries.csv')
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %% [markdown]
# ##Statistical distributions

# %% [markdown]
# ### Histogram

# %%
plt.hist(df['salary'])
# Out:
# (array([ 3., 15., 12., 14.,  9., 11.,  4.,  8.,  1.,  1.]),
#  array([ 57800.,  70716.,  83632.,  96548., 109464., 122380., 135296.,
#         148212., 161128., 174044., 186960.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['salary'], bins=10, linewidth=2, edgecolor="red")
# Out:
# (array([ 3., 15., 12., 14.,  9., 11.,  4.,  8.,  1.,  1.]),
#  array([ 57800.,  70716.,  83632.,  96548., 109464., 122380., 135296.,
#         148212., 161128., 174044., 186960.]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(data=df['salary'],bins=10, linewidth=0.5, edgecolor="white")
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.histplot(data=df['salary'],kde=True)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
import plotly.express as px

px.histogram(df['salary'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Boxplot

# %%
plt.boxplot(df['salary'])
plt.show()

# %%
sns.boxplot(df['salary'])
# Out:
# <Axes: ylabel='salary'>

# %%
sns.boxplot(x=df['salary'])
# Out:
# <Axes: xlabel='salary'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
fig = px.box(df['salary'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(df[['salary', 'service']])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###Pie Plot

# %%
plt.pie(df['service'])
plt.show()

# %%
plt.pie(df['phd'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7d96907047c0>,
# ...
#  [Text(1.092801922104685, 0.12563422720065598, ''),
#   Text(1.0648575561549416, 0.27582310472425176, ''),
#   Text(1.0424184876986693, 0.35123168493747714, ''),
#   Text(0.988684400721884, 0.48218581041877334, ''),
#   Text(0.9222722130857526, 0.5995114385646935, ''),
#   Text(0.8702305296122334, 0.6728289718277686, ''),
#   Text(0.8123749887982895, 0.7416514528907627, ''),
#   Text(0.7523787707027126, 0.8024501139609085, ''),
#   Text(0.6719392522789029, 0.8709177006163493, ''),
#   Text(0.5211989585130821, 0.9686855246388679, ''),
#   Text(0.33521094531015394, 1.0476801144167398, ''),
#   Text(0.20010903689356557, 1.0816452160267385, ''),
#   Text(0.14682899676612557, 1.09015652349039, ''),
#   Text(0.06628687144512392, 1.0980009338220154, ''),
#   Text(-0.06853101251848728, 1.0978631519106519, ''),
#   Text(-0.16241121245987786, 1.0879442072401107, ''),
#   Text(-0.21776835045488568, 1.0782286146917817, ''),
# ...

# %%
df['discipline'].value_counts()
# Out:
# discipline
# B    42
# A    36
# Name: count, dtype: int64

# %%
plt.pie(df['discipline'].value_counts(), labels=['B','A'], autopct='%.0f%%')
plt.show()

# %% [markdown]
# ### Line Plot

# %%
plt.plot([1,2,5,4])
plt.show()

# %% [markdown]
# ### Stair Plot

# %%
plt.stairs(df['salary'], linewidth=2)

# %%
plt.plot(df['phd'], linestyle = '--')
plt.show()

# %% [markdown]
# ##Pairwise data

# %% [markdown]
# ### Line Plot

# %%
plt.plot([1,2,3,4], [3,2,8,6])

# %% [markdown]
# ###Scatter Plot

# %%
plt.scatter(df['service'], df['salary'])

# %%
df[['service','salary']].corr()
# Out:
#           service    salary
# service  1.000000  0.532191
# salary   0.532191  1.000000

# %%
plt.scatter(df['service'], df['salary'])
plt.scatter(df['phd'], df['salary'])

# %%
fig = px.scatter(x=df['service'], y=df['salary'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(x=df['service'], y=df['salary'], color=df["sex"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Bar Plot

# %%
plt.bar(df['salary'], df['phd'], width=1, edgecolor="white", linewidth=0.7)
# Out:
# <BarContainer object of 78 artists>

# %%
plt.bar(df['rank'], df['phd'], width=1, edgecolor="red", linewidth=0.7)
# Out:
# <BarContainer object of 78 artists>

# %%
fig = px.bar(df, x='rank', y='phd')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
